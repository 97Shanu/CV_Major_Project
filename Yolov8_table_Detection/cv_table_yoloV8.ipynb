# %%
# !pip -q install -U ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.97 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %%
# !pip install clearml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.5 MB/s eta 0:00:00
# ...

# %%
import os
os.chdir(os.getcwd())

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -qq /content/drive/MyDrive/CV_PROJECT2/table_data.zip

# %%
	
# !yolo task=detect mode=train model=yolov8n.pt imgsz=640 data="/content/table_data/Table_data.yaml" epochs=100 batch=10 name=yolov8n_custom
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 80.0MB/s]
# Ultralytics YOLOv8.0.97 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo train model=yolov8n.pt data="/content/table_data/Table_data.yaml" epochs=50 imgsz=640 batch=10
# Out:
# New https://pypi.org/project/ultralytics/8.0.97 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.96 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# import torch
# import cv2
# import torchvision.transforms as transforms
# from google.colab.patches import cv2_imshow
# # Load the trained YOLOv5 model
# # model = torch.hub.load('ultralytics/yolov5', 'custom', path='path/to/trained/model.pt')
# #model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
        
# # model = torch.hub.load('/content/','custom', path='yolov8n.pt',force_reload=True,source='local', pretrained =False)
# # Load the test image|
# img = cv2.imread("/content/cv_input.jpg")

# # Transform the image to the required format
# transform = transforms.Compose([
#     transforms.Resize(640),
#     transforms.ToTensor(),
# ])
# cv2_imshow(img)

# %%
	
# !yolo task=detect mode=predict model=/content/yolov8n.pt source="/content/word_database_documentation.png" show=True imgsz=640 name=yolov8n_custom hide_labels=True

# %%
# !yolo detect predict model = yolov8n.pt source = "/content/word_database_documentation.png"

# %%
# # Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='/content/cv_input.jpg'
