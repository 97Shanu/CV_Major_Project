# %%
# !git clone https://github.com/97Shanu/CV_Major_Project.git
# Out:
# Cloning into 'Yolov5_table_Detection'...
# remote: Enumerating objects: 1210, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 1210 (delta 14), reused 21 (delta 5), pack-reused 1171
# Receiving objects: 100% (1210/1210), 41.47 MiB | 17.24 MiB/s, done.
# Resolving deltas: 100% (533/533), done.
# Updating files: 100% (1144/1144), done.

# %%
cd CV_Major_Project/Yolov5_table_Detection
# Out:
# /content/Yolov5_table_Detection

# %%
cd yolov5
# Out:
# /content/Yolov5_table_Detection/yolov5

# %%
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 2023-3-4 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.2/78.2 GB disk)

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 60 --data custom_coco128.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2023-3-4 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp3/weights/best.pt --img 640 --conf 0.25 --source /content/1_33.jpg
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['runs/train/exp3/weights/best.pt'], source=/content/1_33.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-3-4 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/1_33.jpg: 640x448 1 Table, 12.0ms
# Speed: 0.4ms pre-process, 12.0ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp
